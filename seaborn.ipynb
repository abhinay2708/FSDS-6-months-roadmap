# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# %matplotlib inline
plt.rcParams['figure.figsize']=8,4

# %%
df=pd.read_csv(r'C:\Users\abhin\Downloads\data.csv')
df
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
df.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
df['CountryName']
# Out:
# 0                     Aruba
# 1               Afghanistan
# 2                    Angola
# 3                   Albania
# 4      United Arab Emirates
#                ...
# 190             Yemen, Rep.
# 191            South Africa
# 192        Congo, Dem. Rep.
# 193                  Zambia
# 194                Zimbabwe
# Name: CountryName, Length: 195, dtype: object

# %%
sns.distplot(df['BirthRate'])
plt.show()
# Out:
# C:\Users\abhin\AppData\Local\Temp\ipykernel_10200\487485846.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['BirthRate'])

# %%
sns.displot(df['InternetUsers'])
plt.show()

# %%
sns.histplot(df['InternetUsers'])
plt.show()

# %%
sns.histplot(df['InternetUsers'],bins=15)
plt.show()

# %%
sns.boxplot(data=df,x='BirthRate',y='IncomeGroup')
plt.show()

# %%
sns.boxplot(data=df,x='InternetUsers',y='BirthRate')
plt.show()

# %%
sns.boxplot(data=df,x='InternetUsers',y='IncomeGroup')
plt.show()

# %%
sns.lmplot(data=df,x='InternetUsers',y='BirthRate')
plt.show()

# %%
sns.lmplot(data=df,x='InternetUsers',y='BirthRate',fit_reg=False)
plt.show()

# %%
sns.lmplot(data=df,x='InternetUsers',y='BirthRate',fit_reg=True)
plt.show()

# %%
sns.lmplot(data=df,x='InternetUsers',y='BirthRate',fit_reg=True,hue='BirthRate')
plt.show()

# %%
sns.lmplot(data=df,x='InternetUsers',y='BirthRate',fit_reg=False,hue='InternetUsers')
plt.show()

# %%
sns.lmplot(data=df,x='InternetUsers',y='BirthRate',fit_reg=True,hue='BirthRate',height=10)
plt.show()

# %%
sns.barplot(df['BirthRate'])
plt.show()

# %%
sns.barplot(data=df,x='BirthRate',y='IncomeGroup')
plt.show()

# %%
sns.catplot(df['BirthRate'])
plt.show()

# %%
sns.catplot(data=df,x='BirthRate',y='IncomeGroup')
plt.show()

# %%
sns.displot(data=df,x='BirthRate',y='IncomeGroup')
plt.show()

# %%
sns.displot(data=df,x='BirthRate',y='IncomeGroup',hue='BirthRate')
plt.show()
