# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
heart_data=pd.read_csv(r"C:\Users\abhin\Downloads\heart.csv")

# %%
heart_data
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
heart_data.shape
# Out:
# (303, 14)

# %%
heart_data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
heart_data.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
heart_data.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
heart_data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
heart_data.nunique()
# Out:
# age          41
# sex           2
# cp            4
# trestbps     49
# chol        152
# fbs           2
# restecg       3
# thalach      91
# exang         2
# oldpeak      40
# slope         3
# ca            5
# thal          4
# target        2
# dtype: int64

# %%
heart_data['target']
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 298    0
# 299    0
# 300    0
# 301    0
# 302    0
# Name: target, Length: 303, dtype: int64

# %%
heart_data['target'].nunique()
# Out:
# 2

# %%
heart_data['target'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
heart_data['target'].value_counts()
# Out:
# target
# 1    165
# 0    138
# Name: count, dtype: int64

# %%
f,ax=plt.subplots(figsize=(8,6))
sns.countplot(x='target',data=heart_data,hue='target')
# Out:
# <Axes: xlabel='target', ylabel='count'>

# %%
heart_data.groupby('sex')['target'].value_counts()
# Out:
# sex  target
# 0    1          72
#      0          24
# 1    0         114
#      1          93
# Name: count, dtype: int64

# %%
f,ax=plt.subplots(figsize=(8,6))
sns.countplot(data=heart_data,x='sex',hue='target')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.catplot(data=heart_data,x="target",col="sex",kind="count",height=5,aspect=1)

# %%
sns.catplot(x="target", col="sex", data=heart_data, kind="count", height=5, aspect=1,hue='target')

# %%
sns.countplot(data=heart_data,x='target',hue='sex')
# Out:
# <Axes: xlabel='target', ylabel='count'>

# %%
sns.countplot(data=heart_data,x='target',hue='sex')
# Out:
# <Axes: xlabel='target', ylabel='count'>

# %%
sns.countplot(data=heart_data,x='target',palette='Set3')
# Out:
# <Axes: xlabel='target', ylabel='count'>

# %%
sns.countplot(data=heart_data,x="target",facecolor=(0,0,0,0),linewidth=10,edgecolor=sns.color_palette("dark",3))
# Out:
# <Axes: xlabel='target', ylabel='count'>

# %%
plt.figure(figsize=(8, 6))
sns.countplot(
    data=heart_data,
    x="target",
    facecolor=(0, 0, 0, 0),
    linewidth=5,
    edgecolor=sns.color_palette("dark", 2)
)
plt.title("Target Variable Distribution")
plt.xlabel("Target")
plt.ylabel("Count")
plt.show()

# %%
sns.countplot(data=heart_data,x="target",hue="fbs")
# Out:
# <Axes: xlabel='target', ylabel='count'>

# %%
sns.countplot(data=heart_data,x="target",hue="exang")
# Out:
# <Axes: xlabel='target', ylabel='count'>

# %%
correlation=heart_data.corr()

# %%
correlation['target'].sort_values(ascending=False)
# Out:
# target      1.000000
# cp          0.433798
# thalach     0.421741
# slope       0.345877
# restecg     0.137230
# fbs        -0.028046
# chol       -0.085239
# trestbps   -0.144931
# age        -0.225439
# sex        -0.280937
# thal       -0.344029
# ca         -0.391724
# oldpeak    -0.430696
# exang      -0.436757
# Name: target, dtype: float64

# %%
correlation['target'].sort_values(ascending=True)
# Out:
# exang      -0.436757
# oldpeak    -0.430696
# ca         -0.391724
# thal       -0.344029
# sex        -0.280937
# age        -0.225439
# trestbps   -0.144931
# chol       -0.085239
# fbs        -0.028046
# restecg     0.137230
# slope       0.345877
# thalach     0.421741
# cp          0.433798
# target      1.000000
# Name: target, dtype: float64

# %%
heart_data["cp"].nunique()
# Out:
# 4

# %%
heart_data["cp"].value_counts()
# Out:
# cp
# 0    143
# 2     87
# 1     50
# 3     23
# Name: count, dtype: int64

# %%
f,ax=plt.subplots(figsize=(8,6))
sns.countplot(data=heart_data,x="cp",hue='target')
# Out:
# <Axes: xlabel='cp', ylabel='count'>

# %%
heart_data.groupby('cp')['target'].value_counts()
# Out:
# cp  target
# 0   0         104
#     1          39
# 1   1          41
#     0           9
# 2   1          69
#     0          18
# 3   1          16
#     0           7
# Name: count, dtype: int64

# %%
sns.countplot(data=heart_data,x="cp",hue='target')
# Out:
# <Axes: xlabel='cp', ylabel='count'>

# %%
sns.catplot(data=heart_data,x="target",col="cp",kind="count",height=4,aspect=1,hue="target")

# %%
heart_data["thalach"].nunique()
# Out:
# 91

# %%
sns.distplot(heart_data["thalach"],bins=10)
# Out:
# <Axes: xlabel='thalach', ylabel='Density'>

# %%
plt.figure(figsize=(10,6))
sns.distplot(heart_data["thalach"],bins=10)
# Out:
# <Axes: xlabel='thalach', ylabel='Density'>

# %%
sns.distplot(pd.Series(heart_data["thalach"],name="thalach variable"),bins=10)
# Out:
# <Axes: xlabel='thalach variable', ylabel='Density'>

# %%
sns.distplot(pd.Series(heart_data["thalach"],name="thalach variable"),bins=10,vertical=True)
# Out:
# <Axes: xlabel='Density', ylabel='thalach variable'>

# %%
sns.distplot(pd.Series(heart_data["thalach"],name="thalach variable"),bins=10,vertical=False)
# Out:
# <Axes: xlabel='thalach variable', ylabel='Density'>

# %%
sns.kdeplot(pd.Series(heart_data["thalach"],name="thalach variable"))
# Out:
# <Axes: xlabel='thalach variable', ylabel='Density'>

# %%
sns.kdeplot(pd.Series(heart_data["thalach"],name="thalach variable"),shade=True,color='r')
# Out:
# <Axes: xlabel='thalach variable', ylabel='Density'>

# %%
sns.kdeplot(pd.Series(heart_data["thalach"],name="thalach variable"),shade=True,color='g')
# Out:
# <Axes: xlabel='thalach variable', ylabel='Density'>

# %%
sns.distplot(heart_data["thalach"],kde=False,rug=True,bins=10)
# Out:
# <Axes: xlabel='thalach'>

# %%
sns.stripplot(data=heart_data,x="target",y="thalach",hue="target")
# Out:
# <Axes: xlabel='target', ylabel='thalach'>

# %%
sns.stripplot(data=heart_data,x="target",y="thalach",jitter=0.000001,hue="target")
# Out:
# <Axes: xlabel='target', ylabel='thalach'>

# %%
sns.boxplot(data=heart_data,x="target",y="thalach",hue="target")
# Out:
# <Axes: xlabel='target', ylabel='thalach'>

# %%
plt.figure(figsize=(10,8))
plt.title("Correlation  Heatmap of Heart Disease Dataset")
a=sns.heatmap(correlation,square=True,annot=True,fmt='.2f',linecolor='white')
a.set_xticklabels(a.get_xticklabels(),rotation=90)
a.set_yticklabels(a.get_yticklabels(),rotation=30)
# Out:
# [Text(0, 0.5, 'age'),
#  Text(0, 1.5, 'sex'),
#  Text(0, 2.5, 'cp'),
#  Text(0, 3.5, 'trestbps'),
#  Text(0, 4.5, 'chol'),
#  Text(0, 5.5, 'fbs'),
#  Text(0, 6.5, 'restecg'),
#  Text(0, 7.5, 'thalach'),
#  Text(0, 8.5, 'exang'),
#  Text(0, 9.5, 'oldpeak'),
#  Text(0, 10.5, 'slope'),
#  Text(0, 11.5, 'ca'),
#  Text(0, 12.5, 'thal'),
#  Text(0, 13.5, 'target')]

# %%
num_var=["age","trestbps","chol","thalach","oldpeak","target"]
sns.pairplot(heart_data[num_var],kind='scatter',diag_kind='hist')

# %%
sns.pairplot(heart_data[num_var],kind='scatter',diag_kind='hist',hue='target')

# %%
g=sns.PairGrid(heart_data[num_var])
g.map_upper(sns.scatterplot)
g.map_lower(sns.kdeplot,fill=True)
g.map_diag(sns.histplot,kde=True)

# %%
heart_data['age'].nunique()
# Out:
# 41

# %%
heart_data['age'].describe()
# Out:
# count    303.000000
# mean      54.366337
# std        9.082101
# min       29.000000
# 25%       47.500000
# 50%       55.000000
# 75%       61.000000
# max       77.000000
# Name: age, dtype: float64

# %%
sns.distplot(heart_data['age'])
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
sns.stripplot(data=heart_data,x='target',y='age',hue='target')
# Out:
# <Axes: xlabel='target', ylabel='age'>

# %%
sns.boxplot(data=heart_data,x='target',y='age',hue='target')
# Out:
# <Axes: xlabel='target', ylabel='age'>

# %%
sns.scatterplot(data=heart_data,x='age',y='trestbps',hue='age')
# Out:
# <Axes: xlabel='age', ylabel='trestbps'>

# %%
sns.regplot(data=heart_data,x='age',y='trestbps',color='g')
# Out:
# <Axes: xlabel='age', ylabel='trestbps'>

# %%
sns.scatterplot(data=heart_data,x='age',y='chol',hue='age')
# Out:
# <Axes: xlabel='age', ylabel='chol'>

# %%
sns.regplot(data=heart_data,x='age',y='chol')
# Out:
# <Axes: xlabel='age', ylabel='chol'>

# %%
sns.scatterplot(data=heart_data,x='chol',y='thalach',hue='chol')
# Out:
# <Axes: xlabel='chol', ylabel='thalach'>

# %%
sns.regplot(data=heart_data,x='chol',y='thalach')
# Out:
# <Axes: xlabel='chol', ylabel='thalach'>

# %%
heart_data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
heart_data.isnull().any()
# Out:
# age         False
# sex         False
# cp          False
# trestbps    False
# chol        False
# fbs         False
# restecg     False
# thalach     False
# exang       False
# oldpeak     False
# slope       False
# ca          False
# thal        False
# target      False
# dtype: bool

# %%
heart_data.isnull().sum().sum()
# Out:
# 0

# %%
heart_data.isnull().any().any()
# Out:
# False

# %%
heart_data.isnull().mean()
# Out:
# age         0.0
# sex         0.0
# cp          0.0
# trestbps    0.0
# chol        0.0
# fbs         0.0
# restecg     0.0
# thalach     0.0
# exang       0.0
# oldpeak     0.0
# slope       0.0
# ca          0.0
# thal        0.0
# target      0.0
# dtype: float64

# %%
heart_data.isnull().values.any()
# Out:
# False

# %%
heart_data.isnull().values.sum()
# Out:
# 0

# %%
assert pd.notnull(heart_data).all().all()

# %%
assert (heart_data>=0).all().all()

# %%
heart_data.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
heart_data['age'].describe()
# Out:
# count    303.000000
# mean      54.366337
# std        9.082101
# min       29.000000
# 25%       47.500000
# 50%       55.000000
# 75%       61.000000
# max       77.000000
# Name: age, dtype: float64

# %%
sns.boxplot(x=heart_data['age'])
# Out:
# <Axes: xlabel='age'>

# %%
heart_data['trestbps'].describe()
# Out:
# count    303.000000
# mean     131.623762
# std       17.538143
# min       94.000000
# 25%      120.000000
# 50%      130.000000
# 75%      140.000000
# max      200.000000
# Name: trestbps, dtype: float64

# %%
sns.boxplot(x=heart_data['trestbps'])
# Out:
# <Axes: xlabel='trestbps'>

# %%
heart_data['chol'].describe()
# Out:
# count    303.000000
# mean     246.264026
# std       51.830751
# min      126.000000
# 25%      211.000000
# 50%      240.000000
# 75%      274.500000
# max      564.000000
# Name: chol, dtype: float64

# %%
sns.boxplot(x=heart_data['chol'])
# Out:
# <Axes: xlabel='chol'>

# %%
heart_data['thalach'].describe()
# Out:
# count    303.000000
# mean     149.646865
# std       22.905161
# min       71.000000
# 25%      133.500000
# 50%      153.000000
# 75%      166.000000
# max      202.000000
# Name: thalach, dtype: float64

# %%
sns.boxplot(x=heart_data['thalach'])
# Out:
# <Axes: xlabel='thalach'>

# %%
heart_data['oldpeak'].describe()
# Out:
# count    303.000000
# mean       1.039604
# std        1.161075
# min        0.000000
# 25%        0.000000
# 50%        0.800000
# 75%        1.600000
# max        6.200000
# Name: oldpeak, dtype: float64

# %%
sns.boxplot(x=heart_data['oldpeak'])
# Out:
# <Axes: xlabel='oldpeak'>

# %%
heart_data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
heart_data['sex'].describe()
# Out:
# count    303.000000
# mean       0.683168
# std        0.466011
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000
# Name: sex, dtype: float64

# %%
sns.boxplot(x=heart_data['sex'])
# Out:
# <Axes: xlabel='sex'>

# %%
heart_data['cp'].describe()
# Out:
# count    303.000000
# mean       0.966997
# std        1.032052
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        2.000000
# max        3.000000
# Name: cp, dtype: float64

# %%
sns.boxplot(x=heart_data['cp'])
# Out:
# <Axes: xlabel='cp'>
