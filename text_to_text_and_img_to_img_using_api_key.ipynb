# %% [markdown]
# # Install google generative ai

# %%
pip install -q -U google-generativeai
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000024CD7F00F80>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/google-generativeai/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000024CD93881A0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/google-generativeai/
# ...

# %% [markdown]
# # import google generativeai

# %%
import google.generativeai as genai
 
genai.configure(api_key="AIzaSyBQcyYH10fu3maMVY8yverRF7_VhcXGFGE") 

model=genai.GenerativeModel("gemini-2.5-flash-preview-04-17")
response=model.generate_content("can you build summarization table between ai vs gen ai vs agentic ai")
print(response.text)
# Out:
# Okay, here is a summarization table comparing AI, Generative AI, and Agentic AI.
#
# It's important to understand that this represents a nested relationship: **AI** is the broadest term, **Generative AI** is a specific *type* of AI, and **Agentic AI** is often an *architecture* or *system* that *uses* Generative AI and other AI capabilities to achieve goals autonomously.
#
# Here's the table:
#
# | Feature             | Artificial Intelligence (AI)                                   | Generative AI (Gen AI)                                   | Agentic AI (Agent AI)                                          |
# | :------------------ | :------------------------------------------------------------- | :------------------------------------------------------- | :------------------------------------------------------------- |
# ...

# %% [markdown]
# # Import pathlab and textwrap
# # Import display and markown

# %%
import pathlib
import textwrap

import google.generativeai as genai

from IPython.display import display
from IPython.display import Markdown


def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# %%
for m in genai.list_models():
  if 'generateContent' in m.supported_generation_methods:
    print(m.name)
# Out:
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro-vision
# models/gemini-1.5-pro-latest
# models/gemini-1.5-pro-002
# models/gemini-1.5-pro
# models/gemini-1.5-flash-latest
# models/gemini-1.5-flash
# models/gemini-1.5-flash-002
# models/gemini-1.5-flash-8b
# models/gemini-1.5-flash-8b-001
# models/gemini-1.5-flash-8b-latest
# models/gemini-2.5-pro-preview-03-25
# models/gemini-2.5-flash-preview-04-17
# models/gemini-2.5-flash-preview-05-20
# models/gemini-2.5-flash
# models/gemini-2.5-flash-preview-04-17-thinking
# models/gemini-2.5-flash-lite-preview-06-17
# models/gemini-2.5-pro-preview-05-06
# models/gemini-2.5-pro-preview-06-05
# models/gemini-2.5-pro
# models/gemini-2.0-flash-exp
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-exp-image-generation
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.0-flash-preview-image-generation
# models/gemini-2.0-flash-lite-preview-02-05
# ...

# %% [markdown]
# # import PIL.Image

# %%
import PIL.Image

img=PIL.Image.open(r"C:\Users\abhin\OneDrive\Desktop\Images\cat.jpg")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1100x824>

# %% [markdown]
# # Use API key

# %%
model=genai.GenerativeModel('models/gemini-2.5-flash-preview-05-20')

# %% [markdown]
# # Use Image to Text

# %%
response=model.generate_content(img)
to_markdown(response.text)
# Out:
# > This is a close-up, head-on portrait of a cat, focusing on its face from the eyes down to the whiskers.
# >
# > Here's a detailed description:
# > *   **Subject:** The cat is likely a domestic short-haired or medium-haired cat with a distinct tabby pattern.
# > *   **Fur:** The fur is a beautiful blend of colors, primarily various shades of grey, brown, and cream/tan. Darker, well-defined stripes are prominent on the forehead, around the eyes, and across the cheeks, characteristic of a mackerel or classic tabby. The fur around the muzzle and lower face appears softer and lighter in tone.
# > *   **Eyes:** The cat has striking, large green eyes that are looking directly at the viewer. The pupils appear slightly dilated, suggesting either dim lighting or an alert, focused state. There's a clear reflection of a light source, possibly a window, in the right eye (cat's left).
# > *   **Nose:** The nose is small, heart-shaped at the bottom, and a soft, delicate pink color.
# ...

# %%
model=genai.GenerativeModel('models/gemini-2.5-flash-preview-04-17')

# %%
import PIL.Image

img=PIL.Image.open(r"C:\Users\abhin\OneDrive\Desktop\Images\horse.jpg")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=275x183>

# %%
response=model.generate_content(img)
to_markdown(response.text)
# Out:
# > This is a stunning image of a beautiful white horse in motion.
# >
# > Here's a description:
# >
# > The image shows a **pure white horse** captured in a dynamic pose, mid-trot or canter. Its **gleaming white coat** stands out vibrantly against a **dark, lush backdrop of forest foliage and trees**. Sunlight appears to be filtering through, illuminating the horse and highlighting its **flowing mane and tail**. The horse has a bridle or halter on its head. The foreground shows the ground with some patches of grass, and there's a strong patch of sunlight on the lower left.
# >
# > The overall impression is one of **grace, power, and ethereal beauty**, with the horse appearing almost radiant against the deep, natural setting.
